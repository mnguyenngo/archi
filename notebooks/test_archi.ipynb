# %%
cd ..
# Out:
# /Users/nguyen/projects/archi

# %%
from src.archi_nlp import Archi

# %% [markdown]
# ### Create Archi :)

# %%
archi = Archi('en')

# %% [markdown]
# ### Get the raw data

# %%
archi.get_raw_data('data/df/ibc.pkl')

# %%
archi.get_raw_data('data/df/asce7.pkl')

# %%
len(archi.raw_data)
# Out:
# 6051

# %% [markdown]
# ### Add an nlp_doc column to the raw_data using the object's nlp model

# %%
# %time archi.fit_nlp()
# Out:
# CPU times: user 2min 55s, sys: 22.9 s, total: 3min 18s
# Wall time: 2min 8s

# %%
data = archi.raw_nlp_data

# %%
data.loc[6050, 'nlp_doc']
# Out:
# The load effects of the
# design wind pressures from Section 28.6.3 shall not be less than
# a minimum load defined by assuming the pressures, ps, for zones
# A and C equal to +16 psf, Zones B and D equal to +8 psf, while
# assuming ps for Zones E, F, G, and His equal to 0 psf.

# %%
data.head()
# Out:
#                         _id  \
# 0  5acce476ed4f1f214d78ccd0
# 1  5acce476ed4f1f214d78ccd1
# 2  5acce476ed4f1f214d78ccd2
# 3  5acce476ed4f1f214d78ccd3
# 4  5acce476ed4f1f214d78ccd4
#
#                                                 code  \
# 0
# 1
# 2  The provisions of this chapter shall govern sp...
# 3
# 4  The provisions of Sections 3102.1 through 3102...
#
#                               title  \
# 0   Chapter 31 Special Construction
# 1              Section 3101 General
# 2                      3101.1 Scope
# 3  Section 3102 Membrane Structures
# 4                    3102.1 General
#
#                                              nlp_doc
# 0                                                 ()
# 1                                                 ()
# 2  (The, provisions, of, this, chapter, shall, go...
# 3                                                 ()
# 4  (The, provisions, of, Sections, 3102.1, throug...

# %% [markdown]
# ### Save the dataframe with nlp_doc to a pickle

# %%
archi.pickle_raw_nlp('data/nlp_df/raw_0508.pkl')

# %% [markdown]
# ### Create new Archi and get the raw nlp data

# %%
archi = Archi('en')

# %%
archi.get_raw_nlp_data('data/nlp_df/raw_0508.pkl')

# %%
archi.raw_nlp_data
# Out:
#                            _id  \
# 0     5acce476ed4f1f214d78ccd0
# 1     5acce476ed4f1f214d78ccd1
# 2     5acce476ed4f1f214d78ccd2
# 3     5acce476ed4f1f214d78ccd3
# 4     5acce476ed4f1f214d78ccd4
# 5     5acce476ed4f1f214d78ccd5
# 6     5acce476ed4f1f214d78ccd6
# 7     5acce476ed4f1f214d78ccd7
# 8     5acce476ed4f1f214d78ccd8
# 9     5acce476ed4f1f214d78ccd9
# 10    5acce476ed4f1f214d78ccda
# 11    5acce476ed4f1f214d78ccdb
# 12    5acce476ed4f1f214d78ccdc
# 13    5acce476ed4f1f214d78ccdd
# 14    5acce476ed4f1f214d78ccde
# 15    5acce476ed4f1f214d78ccdf
# 16    5acce476ed4f1f214d78cce0
# 17    5acce476ed4f1f214d78cce1
# 18    5acce476ed4f1f214d78cce2
# 19    5acce476ed4f1f214d78cce3
# 20    5acce476ed4f1f214d78cce4
# 21    5acce476ed4f1f214d78cce5
# 22    5acce476ed4f1f214d78cce6
# 23    5acce476ed4f1f214d78cce7
# 24    5acce476ed4f1f214d78cce8
# 25    5acce476ed4f1f214d78cce9
# 26    5acce476ed4f1f214d78ccea
# 27    5acce476ed4f1f214d78cceb
# 28    5acce476ed4f1f214d78ccec
# 29    5acce476ed4f1f214d78cced
# ...                        ...
# 6021  5acc42eeed4f1f1fbcf305a2
# 6022  5acc42eeed4f1f1fbcf305a3
# 6023  5acc42eeed4f1f1fbcf305a4
# 6024  5acc42eeed4f1f1fbcf305a5
# 6025  5acc42eeed4f1f1fbcf305a6
# 6026  5acc42eeed4f1f1fbcf305a7
# 6027  5acc4346ed4f1f1fbcf305c6
# 6028  5acc4346ed4f1f1fbcf305c7
# 6029  5acc4346ed4f1f1fbcf305c8
# 6030  5acc4346ed4f1f1fbcf305c9
# 6031  5acc4346ed4f1f1fbcf305ca
# 6032  5acc4346ed4f1f1fbcf305cb
# 6033  5acc4346ed4f1f1fbcf305cc
# 6034  5acc4346ed4f1f1fbcf305cd
# 6035  5acc4346ed4f1f1fbcf305ce
# 6036  5acc4346ed4f1f1fbcf305cf
# 6037  5acc4346ed4f1f1fbcf305d0
# 6038  5acc4346ed4f1f1fbcf305d1
# 6039  5acc4346ed4f1f1fbcf305d2
# 6040  5acc4346ed4f1f1fbcf305d3
# 6041  5acc4346ed4f1f1fbcf305d4
# 6042  5acc4346ed4f1f1fbcf305d5
# 6043  5acc4346ed4f1f1fbcf305d6
# 6044  5acc4346ed4f1f1fbcf305d7
# 6045  5acc4346ed4f1f1fbcf305d8
# 6046  5acc4346ed4f1f1fbcf305d9
# 6047  5acc4346ed4f1f1fbcf305da
# 6048  5acc4346ed4f1f1fbcf305db
# 6049  5acc4346ed4f1f1fbcf305dc
# 6050  5acc4346ed4f1f1fbcf305dd
#
#                                                    code  \
# 0
# 1
# 2     The provisions of this chapter shall govern sp...
# 3
# 4     The provisions of Sections 3102.1 through 3102...
# 5     Tensile membrane structures, including permane...
# 6     The following terms are defined in Chapter 2: ...
# 7     Noncombustible membrane structures shall be cl...
# 8     Membranes and interior liners shall be either ...
# 9     The area of a membrane structure shall not exc...
# 10    Membrane structures shall not exceed one story...
# 11    Membrane structures shall be permitted to be u...
# 12    A noncombustible membrane shall be permitted f...
# 13    A membrane meeting the fire propagation perfor...
# 14    The structure shall be designed and constructe...
# 15    For membrane-covered frame structures, the mem...
# 16    Air-supported and air-inflated structures shal...
# 17    This inflation system shall consist of one or ...
# 18    In addition to the primary inflation system, i...
# 19    Blower equipment shall meet all of the followi...
# 20    Wherever an auxiliary inflation system is requ...
# 21    A system capable of supporting the membrane in...
# 22
# 23    The provisions of this section Sections 3103.1...
# 24    Temporary structures and uses shall conform to...
# 25    Temporary structures that cover an area greate...
# 26    A permit application and construction document...
# 27    Temporary structures shall be located in accor...
# 28    Temporary structures shall conform to the mean...
# 29
# ...                                                 ...
# 6021  Glazed openings shall\nbe protected in accorda...
# 6022  Glazing in buildings requiring protection shal...
# 6023  If a building by definition\ncomplies with bot...
# 6024
# 6025  Internal pressure coefficients, (GCpi), shall ...
# 6026  For a partially enclosed building containing a...
# 6027
# 6028
# 6029  This chapter applies to the determination\nof ...
# 6030  A building whose design wind loads are\ndeterm...
# 6031  The provisions of this chapter take into\ncons...
# 6032  There shall be no reductions in velocity press...
# 6033  The steps required for the determination of MW...
# 6034  The\nfollowing wind load parameters shall be d...
# 6035
# 6036  Based on the\nexposure category determined in ...
# 6037  Velocity pressure, qz, evaluated at\nheight z ...
# 6038
# 6039  Design\nwind pressures for the MWFRS of low-ri...
# 6040  The combined\ngust-effect factor and external ...
# 6041  The design wind pressure for the effect of\npa...
# 6042  The positive external pressure on the\nbottom ...
# 6043  The wind load to be\nused in the design of the...
# 6044  The steps required for the determination of MW...
# 6045  The\nfollowing wind load parameters are specif...
# 6046
# 6047  A building whose design wind loads are determi...
# 6048  For the design of MWFRS the building\nshall co...
# 6049  Simplified design wind pressures,\nps, for the...
# 6050  The load effects of the\ndesign wind pressures...
#
#                                                   title  \
# 0                       Chapter 31 Special Construction
# 1                                  Section 3101 General
# 2                                          3101.1 Scope
# 3                      Section 3102 Membrane Structures
# 4                                        3102.1 General
# 5                  3102.1.1 Tensile Membrane Structures
# 6                                    3102.2 Definitions
# 7                           3102.3 Type of Construction
# 8         3102.3.1 Membrane and Interior Liner Material
# 9                          3102.4 Allowable Floor Areas
# 10                                3102.5 Maximum Height
# 11                            3102.6 Mixed Construction
# 12                     3102.6.1 Noncombustible Membrane
# 13                                  3102.6.1.1 Membrane
# 14                            3102.7 Engineering Design
# 15                           3102.7.1 Lateral Restraint
# 16                             3102.8 Inflation Systems
# 17                      3102.8.1 Equipment Requirements
# 18                3102.8.1.1 Auxiliary Inflation System
# 19                          3102.8.1.2 Blower Equipment
# 20                               3102.8.2 Standby Power
# 21                          3102.8.3 Support Provisions
# 22                    Section 3103 Temporary Structures
# 23                                       3103.1 General
# 24                                 3103.1.1 Conformance
# 25                             3103.1.2 Permit Required
# 26                        3103.2 Construction Documents
# 27                                      3103.3 Location
# 28                               3103.4 Means of Egress
# 29         Section 3104 Pedestrian Walkways and Tunnels
# ...                                                 ...
# 6021                26.10.3.1 Wind-Borne Debris Regions
# 6022  26.10.3.2 Protection Requirements for Glazed O...
# 6023                   26.10.4 Multiple Classifications
# 6024                26.11 Internal Pressure Coefficient
# 6025             26.11.1 Internal Pressure Coefficients
# 6026  26.11.1.1 Reduction Factor for Large Volume Bu...
# 6027  Chapter 28 Wind Loads on Buildings‒MWFRS (Enve...
# 6028                                         28.1 Scope
# 6029                              28.1.1 Building Types
# 6030                                  28.1.2 Conditions
# 6031                                 28.1.3 Limitations
# 6032                                   28.1.4 Shielding
# 6033                          28.2 General Requirements
# 6034  28.2.1 Wind Load Parameters Specified in Chapt...
# 6035                             28.3 Velocity Pressure
# 6036      28.3.1 Velocity Pressure Exposure Coefficient
# 6037                           28.3.2 Velocity Pressure
# 6038   28.4 Wind Loads—Main Wind-force Resisting System
# 6039  28.4.1 Design Wind Pressure for Low-Rise Build...
# 6040     28.4.1.1 External Pressure Coefficients (GCpf)
# 6041                                    28.4.2 Parapets
# 6042                              28.4.3 Roof Overhangs
# 6043                   28.4.4 Minimum Design Wind Loads
# 6044                          28.5 General Requirements
# 6045  28.5.1 Wind Load Parameters Specified in Chapt...
# 6046   28.6 Wind Loads—Main Wind-Force Resisting System
# 6047                                       28.6.1 Scope
# 6048                                  28.6.2 Conditions
# 6049                           28.6.3 Design Wind Loads
# 6050                   28.6.4 Minimum Design Wind Loads
#
#                                                 nlp_doc
# 0                                                    ()
# 1                                                    ()
# 2     (The, provisions, of, this, chapter, shall, go...
# 3                                                    ()
# 4     (The, provisions, of, Sections, 3102.1, throug...
# 5     (Tensile, membrane, structures, ,, including, ...
# 6     (The, following, terms, are, defined, in, Chap...
# 7     (Noncombustible, membrane, structures, shall, ...
# 8     (Membranes, and, interior, liners, shall, be, ...
# 9     (The, area, of, a, membrane, structure, shall,...
# 10    (Membrane, structures, shall, not, exceed, one...
# 11    (Membrane, structures, shall, be, permitted, t...
# 12    (A, noncombustible, membrane, shall, be, permi...
# 13    (A, membrane, meeting, the, fire, propagation,...
# 14    (The, structure, shall, be, designed, and, con...
# 15    (For, membrane, -, covered, frame, structures,...
# 16    (Air, -, supported, and, air, -, inflated, str...
# 17    (This, inflation, system, shall, consist, of, ...
# 18    (In, addition, to, the, primary, inflation, sy...
# 19    (Blower, equipment, shall, meet, all, of, the,...
# 20    (Wherever, an, auxiliary, inflation, system, i...
# 21    (A, system, capable, of, supporting, the, memb...
# 22                                                   ()
# 23    (The, provisions, of, this, section, Sections,...
# 24    (Temporary, structures, and, uses, shall, conf...
# 25    (Temporary, structures, that, cover, an, area,...
# 26    (A, permit, application, and, construction, do...
# 27    (Temporary, structures, shall, be, located, in...
# 28    (Temporary, structures, shall, conform, to, th...
# 29                                                   ()
# ...                                                 ...
# 6021  (Glazed, openings, shall, \n, be, protected, i...
# 6022  (Glazing, in, buildings, requiring, protection...
# 6023  (If, a, building, by, definition, \n, complies...
# 6024                                                 ()
# 6025  (Internal, pressure, coefficients, ,, (, GCpi,...
# 6026  (For, a, partially, enclosed, building, contai...
# 6027                                                 ()
# 6028                                                 ()
# 6029  (This, chapter, applies, to, the, determinatio...
# 6030  (A, building, whose, design, wind, loads, are,...
# 6031  (The, provisions, of, this, chapter, take, int...
# 6032  (There, shall, be, no, reductions, in, velocit...
# 6033  (The, steps, required, for, the, determination...
# 6034  (The, \n, following, wind, load, parameters, s...
# 6035                                                 ()
# 6036  (Based, on, the, \n, exposure, category, deter...
# 6037  (Velocity, pressure, ,, qz, ,, evaluated, at, ...
# 6038                                                 ()
# 6039  (Design, \n, wind, pressures, for, the, MWFRS,...
# 6040  (The, combined, \n, gust, -, effect, factor, a...
# 6041  (The, design, wind, pressure, for, the, effect...
# 6042  (The, positive, external, pressure, on, the, \...
# 6043  (The, wind, load, to, be, \n, used, in, the, d...
# 6044  (The, steps, required, for, the, determination...
# 6045  (The, \n, following, wind, load, parameters, a...
# 6046                                                 ()
# 6047  (A, building, whose, design, wind, loads, are,...
# 6048  (For, the, design, of, MWFRS, the, building, \...
# 6049  (Simplified, design, wind, pressures, ,, \n, p...
# 6050  (The, load, effects, of, the, \n, design, wind...
#
# [6051 rows x 4 columns]
